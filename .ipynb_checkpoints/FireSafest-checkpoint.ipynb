# %% [markdown]
# The best Neighborhood would be the one that's the safest to live in, which in this dataset's case the one with the least amount of fire-related incidents

# %%
import pandas as pd

# Open data
df = pd.read_csv("FireDataSet.csv")

# Convert  to string 
df['address'] = df['address'].astype(str)

# only looks at Pittsburgh
pgh_calls = df[df['address'].str.contains('PITTSBURGH', case=False, na=False)]

# incidents
counts = pgh_calls['neighborhood'].value_counts().reset_index()
counts.columns = ['Neighborhood', 'Number of Incidents']

# fewest to most
least_incidents = counts.sort_values(by='Number of Incidents', ascending=True)

print("Neighborhoods in Pittsburgh with the fewest incidents:")

print(least_incidents.head(10))
# Out:
# Neighborhoods in Pittsburgh with the fewest incidents:
#             Neighborhood  Number of Incidents
# 90  Mount Oliver Borough                    7
# 89         Regent Square                    7
# 88         East Carnegie                   11
# 86             Ridgemont                   12
# 87            Mt. Oliver                   12
# 84     Arlington Heights                   13
# 85               Oakwood                   13
# 83             St. Clair                   15
# 82        Swisshelm Park                   17
# 81        Chartiers City                   18

# %% [markdown]
# Looking at this information this puts Mount Oliver Borough and Regent Square are tied as the safest neighborhoods but theres two other data sets that need to first be looked at.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import pandas as pd
import numpy as np
# %matplotlib inline

# Load dataset
df = pd.read_csv("FireDataSet.csv")

# Ensure 'address' is treated as text
df['address'] = df['address'].astype(str)

# Filter for only Pittsburgh addresses
pgh_calls = df[df['address'].str.contains('PITTSBURGH', case=False, na=False)]

# Count incidents per neighborhood
counts = pgh_calls['neighborhood'].value_counts().reset_index()
counts.columns = ['Neighborhood', 'Number_of_Incidents']

# Sort ascending by incident count
counts = counts.sort_values(by='Number_of_Incidents', ascending=True)

# Create a CSV-style string of the chart
chart = "Neighborhood,Number_of_Incidents\n"
chart += "\n".join([f"{row['Neighborhood']},{row['Number_of_Incidents']}" for _, row in counts.iterrows()])

# Print it so you can see what it looks like
print(chart)
# Out:
# Neighborhood,Number_of_Incidents
# Mount Oliver Borough,7
# Regent Square,7
# East Carnegie,11
# Ridgemont,12
# Mt. Oliver,12
# Arlington Heights,13
# Oakwood,13
# St. Clair,15
# Swisshelm Park,17
# Chartiers City,18
# Summer Hill,21
# Glen Hazel,21
# New Homestead,22
# Bon Air,23
# West End,23
# Esplen,23
# Hays,24
# Windgap,25
# Spring Garden,27
# Fairywood,27
# South Shore,28
# Westwood,29
# Friendship,34
# Morningside,38
# Polish Hill,40
# Duquesne Heights,43
# Allegheny West,44
# Chateau,44
# California-Kirkbride,45
# Bedford Dwellings,49
# Point Breeze North,52
# Upper Hill,53
# Fineview,54
# Arlington,55
# Upper Lawrenceville,58
# Banksville,62
# Overbrook,63
# Allegheny Center,63
# Stanton Heights,64
# Homewood West,65
# Lower Lawrenceville,67
# Northview Heights,67
# West Oakland,68
# Lincoln Place,72
# Strip District,75
# Elliott,75
# Point Breeze,78
# Central Lawrenceville,80
# Manchester,84
# Highland Park,86
# Terrace Village,88
# Crafton Heights,89
# Troy Hill,89
# North Shore,91
# Central Oakland,104
# South Oakland,104
# Middle Hill,110
# South Side Slopes,115
# Perry North,117
# Crawford-Roberts,117
# Spring Hill-City View,119
# Garfield,121
# Greenfield,129
# Larimer,130
# North Oakland,136
# Allentown,136
# Central Northside,139
# Beltzhoover,141
# Squirrel Hill North,142
# East Allegheny,142
# Bluff,159
# Marshall-Shadeland,162
# East Hills,163
# Beechview,163
# Brighton Heights,163
# Perry South,174
# Sheraden,181
# Bloomfield,191
# Homewood North,197
# Shadyside,201
# Knoxville,205
# Lincoln-Lemington-Belmar,206
# Brookline,209
# Homewood South,209
# East Liberty,230
# Mount Washington,238
# Hazelwood,264
# Squirrel Hill South,281
# Central Business District,304
# South Side Flats,307
# Carrick,328
